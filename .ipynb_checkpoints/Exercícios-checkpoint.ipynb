# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sigma = np.linspace(0,50, 1000)
m = 15
sigma_0 = 20
weibull_pdf = lambda sigma, m, sigma_0: (m/sigma_0)*(sigma/sigma_0)**(m-1)*np.exp(-(sigma/sigma_0)**m)
weibull_cdf = lambda sigma, m, sigma_0: np.exp(-(sigma/sigma_0)**m)

ax1 = plt.subplot()
ax2 = ax1.twinx()

ax1.plot(sigma, weibull_pdf(sigma, 50, 20), c='Navy', label='$\sigma_0$ =20,  m = 50')

# %%
sigma = np.linspace(0,50, 1000)
m = 15
sigma_0 = 20
weibull_pdf = lambda sigma, m, sigma_0: (m/sigma_0)*(sigma/sigma_0)**(m-1)*np.exp(-(sigma/sigma_0)**m)
weibull_cdf = lambda sigma, m, sigma_0: np.exp(-(sigma/sigma_0)**m)

ax1 = plt.subplot()
ax2 = ax1.twinx()

ax1.plot(sigma, weibull_pdf(sigma, 50, 20), c='Navy', label='$\sigma_0$ =20,  m = 50')
ax2.plot(sigma, weibull_cdf(sigma, 50, 20), c='Navy', lw=1, ls='--')
ax1.plot(sigma, weibull_pdf(sigma, 5, 20), c='red', label='$\sigma_0$ =20, m = 5')
ax2.plot(sigma, weibull_cdf(sigma, 5, 20), c='red', lw=1, ls='--')

ax1.legend(fontsize=14)

ax1.set_ylabel('Probability Density Function')
ax2.set_ylabel('Cumulative Distribution Function')
for ax in [ax1, ax2]:
    ax.set_xlim(0,50)
    ax.set_ylim(0,1.05)

ax1.grid()

plt.show()
#

# %%
# %matplotlib notebook
from ipywidgets import *
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2 * np.pi)
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
line, = ax.plot(x, np.sin(x))

def update(w = 1.0):
    line.set_ydata(np.sin(w * x))
    fig.canvas.draw_idle()

interact(update)
# Out:
# <img src="data:image/png;base64,..." width="432">
# interactive(children=(FloatSlider(value=1.0, description='w', max=3.0, min=-1.0), Output()), _dom_classes=('wi…
# <function __main__.update(w=1.0)>

# %%
sigma_0=20e6
m=50
E=400e9
sigma = np.linspace(0, 50e6, 1000)
sigma_P = weibull_pdf(sigma, m, sigma_0)
sigma_f = np.random.choice(sigma, p=sigma_P)
sigma_fs, sigma_f
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-c21981117089> in <module>
#       4 sigma = np.linspace(0, 50e6, 1000)
#       5 sigma_P = weibull_pdf(sigma, m, sigma_0)
# ----> 6 sigma_f = np.random.choice(sigma, p=sigma_P)
#       7 sigma_fs, sigma_f
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: probabilities do not sum to 1

# %%
plt.hist(np.random.weibull(50, 10000)*20, 100, density=True)
sigma = np.linspace(0,50, 1000)
plt.plot(sigma, weibull_pdf(sigma, 50, 20), c='Navy', label='$\sigma_0$ =20,  m = 50')

plt.show()

# %%
np.random.weibull(50, 1)*20
# Out:
# array([19.17657009])

# %%
np.sum(sigma_P)
# Out:
# 1.9980000000000046e-05

# %%
def run_test(epsilon_i, E, sigma_f):
    if epsilon_i * E < sigma_f:
        epsilons = np.linspace(0, epsilon_i, 1000)
        sigmas = E*epsilons
    else:
        epsilons = np.linspace(0, epsilon_i, 1000)
        sigmas = E*epsilons
        sigmas[sigmas>sigma_f] = np.zeros(sigmas[sigmas>sigma_f].shape[0])
    return epsilons, sigmas

# %%
# Too slow

def f(epsilon_i):
    fig, axs = plt.subplots(5, 1, sharex=True, sharey=True)
    epsilons_1, sigmas_1 = run_test(epsilon_i, E, sigma_f_1)
    epsilons_2, sigmas_2 = run_test(epsilon_i, E, sigma_f_2)
    axs[0].plot(epsilons_1*100, sigmas_1*1e-6, label='Amostra 1')
    axs[0].text(5e-4, 25, str(round(sigma_f_1[0]*1e-6, 2)))
    axs[1].plot(epsilons_2*100, sigmas_2*1e-6, label='Amostra 2')
    axs[1].text(5e-4, 25, str(round(sigma_f_2[0]*1e-6, 2)))
    for ax in axs:
        ax.set_ylim(0, 30)
        ax.set_xlim(0, 0.2e-3*100)
        ax.grid()
        ax.legend()

    plt.ylabel('Tensão, $\sigma$ [MPa]')
    plt.xlabel('Deformação, $\epsilon$ [-]')
    plt.tight_layout()
    plt.show()

# %%
str(round(sigma_f_1[0]*1e-6, 2))
# Out:
# '19.61'

# %%
from adjustText import adjust_text

# %%
ytable = plt.table(cellText=[['Amostra 1', round(sigma_f_1[0]*1e-6, 2)],
                    ['Amostra 1', round(sigma_f_2[0]*1e-6, 2)],
                    ['Amostra 1', round(sigma_f_3[0]*1e-6, 2)],
                    ['Amostra 1', round(sigma_f_4[0]*1e-6, 2)],
                    [r'Amostra 1', round(sigma_f_5[0]*1e-6, 2)]],
                    colLabels=['Amostras', 'Tensão de Falha'],
                    bbox=[0.25, -0.45, 0.5, 0.275])
cellDict = ytable.get_celld()
for i in range(0,2):
    cellDict[(0,i)].set_height(.6)
    for j in range(0,5+1):
        cellDict[(j,i)].set_height(1.6)

# %%
# %matplotlib inline
xs = np.linspace(20, 600)
m=3
E=400e9
sigma_0=20e6
sigma_f_1 = np.random.weibull(m, 1)*sigma_0
sigma_f_2 = np.random.weibull(m, 1)*sigma_0
sigma_f_3 = np.random.weibull(m, 1)*sigma_0
sigma_f_4 = np.random.weibull(m, 1)*sigma_0
sigma_f_5 = np.random.weibull(m, 1)*sigma_0

def f(epsilon_i):
    epsilons_1, sigmas_1 = run_test(epsilon_i, E, sigma_f_1)
    epsilons_2, sigmas_2 = run_test(epsilon_i, E, sigma_f_2)
    epsilons_3, sigmas_3 = run_test(epsilon_i, E, sigma_f_3)
    epsilons_4, sigmas_4 = run_test(epsilon_i, E, sigma_f_4)
    epsilons_5, sigmas_5 = run_test(epsilon_i, E, sigma_f_5)

    plt.plot(epsilons_1*100, sigmas_1*1e-6, c='Navy', label='Amostra 1')
    plt.plot(epsilons_2*100, sigmas_2*1e-6, c='blue', label='Amostra 2')
    plt.plot(epsilons_3*100, sigmas_3*1e-6, c='orange', label='Amostra 3')
    plt.plot(epsilons_4*100, sigmas_4*1e-6, c='crimson', label='Amostra 4')
    plt.plot(epsilons_5*100, sigmas_5*1e-6, c='olive', label='Amostra 5')
    if epsilon_i * E >= sigma_f_1 and epsilon_i * E >= sigma_f_2 and epsilon_i * E >= sigma_f_3 and epsilon_i * E >= sigma_f_4 and epsilon_i * E >= sigma_f_5:
        ytable = plt.table(cellText=[['Amostra 1', round(sigma_f_1[0]*1e-6, 2)],
                                     ['Amostra 2', round(sigma_f_2[0]*1e-6, 2)],
                                     ['Amostra 3', round(sigma_f_3[0]*1e-6, 2)],
                                     ['Amostra 4', round(sigma_f_4[0]*1e-6, 2)],
                                     ['Amostra 5', round(sigma_f_5[0]*1e-6, 2)]],
                                     colLabels=['Amostras', 'Tensão de Falha'],
                                     bbox=[0.25, -0.45, 0.5, 0.275])


        
    plt.ylim(0, 40)
    plt.xlim(0, 0.125e-3*100)
    plt.ylabel('Tensão, $\sigma$ [MPa]')
    plt.xlabel('Deformação, $\epsilon$ [-]')
    plt.grid()
    plt.legend()
    plt.show()

int_plot = interactive(f,
#                        epsilon_i=(0, 1e-4, 0.1e-5),
                         epsilon_i=widgets.FloatSlider(value=0,
                                                       min=0,
                                                       max=1e-4,
                                                       step=1e-5,
                                                       name='$\epsilon$',
                                                       readout_format='.2e')
                      )
output = int_plot.children[-1]
output.layout.height = '350px'
int_plot
# Out:
# interactive(children=(FloatSlider(value=0.0, description='epsilon_i', max=0.0001, readout_format='.2e', step=1…
